# %% [markdown]
# ## Dataset analysis: `high_schools_dimension.csv`
#
# Purpose: high school reference with tier and ownership. Used to enrich student recruitment/high-school linkage.

# %%
from pathlib import Path
import pandas as pd

pd.set_option("display.max_columns", 200)
DATA_DIR = Path.cwd()
df = pd.read_csv(DATA_DIR / "high_schools_dimension.csv")
df.shape
# Out:
# (73, 4)

# %%
df.head()
# Out:
#                  SCHOOL_NAME DISTRICT SCHOOL_TIER            OWNERSHIP
# 0        King's College Budo  Kampala      Tier 1  Private/Faith-based
# 1               Ntare School  Kampala      Tier 1         Public/Mixed
# 2  St. Mary's College Kisubi  Kampala      Tier 1  Private/Faith-based
# 3         Gayaza High School  Kampala      Tier 1  Private/Faith-based
# 4     Namagunga Girls School  Kampala      Tier 1  Private/Faith-based

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# SCHOOL_NAME    0.0
# DISTRICT       0.0
# SCHOOL_TIER    0.0
# OWNERSHIP      0.0
# dtype: float64

# %%
key = ["SCHOOL_NAME", "DISTRICT"]
df.duplicated(key).sum(), df[key].isna().any(axis=1).sum()
# Out:
# (np.int64(0), np.int64(0))

# %%
df["SCHOOL_TIER"].value_counts(dropna=False)
# Out:
# SCHOOL_TIER
# Tier 2    58
# Tier 1    15
# Name: count, dtype: int64

# %%
df["OWNERSHIP"].value_counts(dropna=False)
# Out:
# OWNERSHIP
# Public/Mixed           40
# Private/Faith-based    33
# Name: count, dtype: int64

# %% [markdown]
# ## Advanced analytics
#
# Focus: coverage and consistency with `student_high_schools_all` and CGPA by school tier/ownership when joined.

# %%
from analysis_utils import basic_profile, missingness_report

print(basic_profile(df))
missingness_report(df, top_n=20)
# Out:
# BasicProfile(rows=73, cols=4, dup_rows=0, null_cells=0)
#             dtype  missing_rate  missing_count  nunique
# SCHOOL_NAME   str           0.0              0       73
# DISTRICT      str           0.0              0       42
# SCHOOL_TIER   str           0.0              0        2
# OWNERSHIP     str           0.0              0        2

# %%
# Coverage vs student_high_schools_all
students = pd.read_csv(DATA_DIR / "student_high_schools_all.csv")

merged = students.merge(df, left_on=["HIGH_SCHOOL","DISTRICT"], right_on=["SCHOOL_NAME","DISTRICT"], how="left")

merged["SCHOOL_TIER"].isna().mean(), merged["OWNERSHIP"].isna().mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SCHOOL_TIER'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 6
# ...
